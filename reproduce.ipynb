# %%
# !cp drive/MyDrive/DLH/eda.zip .

# %%
# !unzip eda.zip
# Out:
# Archive:  eda.zip
#    creating: contrastive-learning-for-eda/
#   inflating: contrastive-learning-for-eda/requirements.txt
#   inflating: contrastive-learning-for-eda/uv.lock
#    creating: contrastive-learning-for-eda/loss/
#  extracting: contrastive-learning-for-eda/loss/__init__.py
#   inflating: contrastive-learning-for-eda/loss/contrastive_loss.py
#   inflating: contrastive-learning-for-eda/loss/cross_entropy_loss.py
#    creating: contrastive-learning-for-eda/config/
#   inflating: contrastive-learning-for-eda/config/eval-template-config.json
#   inflating: contrastive-learning-for-eda/config/contrastive-pretrain-template-config.json
#   inflating: contrastive-learning-for-eda/config/contrastive-pretrain-config.json
#   inflating: contrastive-learning-for-eda/Makefile
#   inflating: contrastive-learning-for-eda/pyproject.toml
#   inflating: contrastive-learning-for-eda/run_exp.py
#    creating: contrastive-learning-for-eda/datasets/
# ...

# %%
# !cd contrastive-learning-for-eda && uv sync
# Out:
# Streaming output truncated to the last 5000 lines.
# nvidia-cudnn-cu12 ------------------------------ 56.64 MiB/544.54 MiB
# ⠸ Preparing packages... (121/133)
# plotly     ------------------------------ 8.22 MiB/14.12 MiB
# pyarrow    ------------------------------ 39.53 MiB/40.13 MiB
# ray        ------------------------------ 53.05 MiB/65.24 MiB
# triton     ------------------------------ 58.00 MiB/149.27 MiB
# nvidia-cusparselt-cu12 ------------------------------ 57.23 MiB/149.52 MiB
# nvidia-cusolver-cu12 ------------------------------ 56.92 MiB/150.90 MiB
# nvidia-cufft-cu12 ------------------------------ 56.84 MiB/190.95 MiB
# nvidia-nccl-cu12 ------------------------------ 56.78 MiB/191.99 MiB
# nvidia-cusparse-cu12 ------------------------------ 56.31 MiB/206.53 MiB
# nvidia-cublas-cu12 ------------------------------ 56.95 MiB/374.93 MiB
# nvidia-cudnn-cu12 ------------------------------ 56.97 MiB/544.54 MiB
# ⠸ Preparing packages... (121/133)
# ...

# %%
# !cd contrastive-learning-for-eda && make pretrain
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 22 | Batch 161/201 | Loss: 3.844713 | Speed: 342.4 ex/s | Progress: 80.1% | ETA: 0m 1s
# Epoch 22 | Batch 181/201 | Loss: 4.075986 | Speed: 389.6 ex/s | Progress: 90.0% | ETA: 0m 0s
# Epoch 22 | Batch 201/201 | Loss: 3.915500 | Speed: 605.8 ex/s | Progress: 100.0% | ETA: 0m 0s
# Epoch 22 completed in 0m 7s | Mean loss: 3.994017 | Samples: 2613
# Epoch 23 | Batch 1/201 | Loss: 3.967326 | Speed: 0.0 ex/s | Progress: 0.5% | ETA: calculating...
# Epoch 23 | Batch 21/201 | Loss: 3.980680 | Speed: 330.3 ex/s | Progress: 10.4% | ETA: 0m 13s
# Epoch 23 | Batch 41/201 | Loss: 4.205183 | Speed: 334.3 ex/s | Progress: 20.4% | ETA: 0m 9s
# Epoch 23 | Batch 61/201 | Loss: 3.910774 | Speed: 410.0 ex/s | Progress: 30.3% | ETA: 0m 6s
# Epoch 23 | Batch 81/201 | Loss: 3.963639 | Speed: 303.9 ex/s | Progress: 40.3% | ETA: 0m 5s
# Epoch 23 | Batch 101/201 | Loss: 3.872691 | Speed: 439.3 ex/s | Progress: 50.2% | ETA: 0m 4s
# ...

# %%
# !cd contrastive-learning-for-eda && make eval
# Out:
# Streaming output truncated to the last 5000 lines.
# - loss: 0.6806621540852679
# - accuracy: 0.44715447154471544
# - AUC: 0.912501968607276
# - cross_entropy: 0.6826271671745324
# - confusion_matrix: [[103, 340], [0, 172]]
#
# Epoch 1 | Batch 1/19 | Loss: 0.684721 | Speed: 0.0 ex/s | Progress: 5.3% | ETA: calculating...
# Epoch 1 | Batch 2/19 | Loss: 0.654055 | Speed: 2130.9 ex/s | Progress: 10.5% | ETA: 0m 1s
# Epoch 1 | Batch 3/19 | Loss: 0.646866 | Speed: 1169.9 ex/s | Progress: 15.8% | ETA: 0m 1s
# Epoch 1 | Batch 4/19 | Loss: 0.683129 | Speed: 2073.7 ex/s | Progress: 21.1% | ETA: 0m 0s
# Epoch 1 | Batch 5/19 | Loss: 0.671347 | Speed: 2103.9 ex/s | Progress: 26.3% | ETA: 0m 0s
# Epoch 1 | Batch 6/19 | Loss: 0.692394 | Speed: 2027.7 ex/s | Progress: 31.6% | ETA: 0m 0s
# Epoch 1 | Batch 7/19 | Loss: 0.669207 | Speed: 2233.0 ex/s | Progress: 36.8% | ETA: 0m 0s
# Epoch 1 | Batch 8/19 | Loss: 0.684591 | Speed: 2111.2 ex/s | Progress: 42.1% | ETA: 0m 0s
# ...
